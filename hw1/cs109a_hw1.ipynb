# %% [markdown]
# # CS 109A/STAT 121A/AC 209A/CSCI E-109A: Homework 1
#
#
#
# **Harvard University**<br/>
# **Fall 2017**<br/>
# **Instructors**: Pavlos Protopapas, Kevin Rader, Rahul Dave, Margo Levine
#
# ---
#
# ### INSTRUCTIONS
#
# **WARNING**: There is web page scraping in this homework. It takes about 40 minutes. **Do not wait till the last minute** to do this homework.
#
# - To submit your assignment follow the instructions given in canvas.
# - Restart the kernel and run the whole notebook again before you submit. There is an important CAVEAT to this. DO NOT run the web-page fetching cells again. (We have provided hints like `# DO NOT RERUN THIS CELL WHEN SUBMITTING` on some of the cells where we provide the code). Instead load your data structures from the JSON files we will ask you to save below. Otherwise you will be waiting for a long time. (Another reason to not wait until the last moment to submit.)
#
# - Do not include your name in the notebook.
#
# ---

# %% [markdown]
# # Homework 1: Rihanna or Mariah?

# %% [markdown]
# Billboard Magazine puts out a top 100 list of "singles" every week. Information from this list, as well as that from music sales, radio, and other sources is used to determine a top-100 "singles" of the year list. A **single** is typically one song, but sometimes can be two songs which are on one "single" record.
#
# In this homework you will:
#
# 1. Scrape Wikipedia to obtain infprmation about the best singers and groups from each year (distinguishing between the two groups) as determined by the Billboard top 100 charts. You will have to clean this data. Along the way you will learn how to save data in json files to avoid repeated scraping.
# 2. Scrape Wikipedia to obtain information on these singers. You will have to scrape the web pages, this time using a cache to guard against network timeouts (or your laptop going to sleep). You will again clean the data, and save it to a json file.
# 3. Use pandas to represent these two datasets and merge them.
# 4. Use the individual and merged datasets to visualize the performance of the artists and their songs. We have kept the amount of analysis limited here for reasons of time; but you might enjoy exploring music genres and other aspects of the music business you can find on these wikipedia pages at your own leisure.

# %% [markdown]
# You should have worked through Lab0 and Lab 1, and Lecture 2.  Lab 2 will help as well.

# %% [markdown]
# As usual, first we import the necessary libraries.  In particular, we use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape Wikipedia for the Billboard's top 100 singles.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using  [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/), and suggest that you use Python's built in `requests` library to fetch the web page.

# %% [markdown]
# #### 1.1 Parsing the Billboard Wikipedia page for 1970

# %%
import requests
req = requests.get("http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970")

# %% [markdown]
# Obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970 using a HTTP GET request. From this web page we'll extract the top 100 singles and their rankings. Create a list of dictionaries, 100 of them to be precise, with entries like
#
# `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# If you look at that web page, you'll see a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# *HINT: look for a table with class `wikitable`.*

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(yearstext['1997'], 'html.parser')
table = soup.find(class_ = 'wikitable')
table
# Out:
# <table class="wikitable sortable" style="text-align: center">
# <tr>
# <th scope="col" style="background:#dde;">№</th>
# <th scope="col" style="background:#dde;">Title</th>
# <th scope="col" style="background:#dde;">Artist(s)</th>
# </tr>
# <tr>
# <th scope="row">1</th>
# <td>"<a href="/wiki/Something_About_the_Way_You_Look_Tonight" title="Something About the Way You Look Tonight">Something About the Way You Look Tonight</a>" / "<a href="/wiki/Candle_in_the_Wind_1997" title="Candle in the Wind 1997">Candle in the Wind 1997</a>"</td>
# <td><a href="/wiki/Elton_John" title="Elton John">Elton John</a></td>
# </tr>
# <tr>
# <th scope="row">2</th>
# <td>"<a href="/wiki/Foolish_Games" title="Foolish Games">Foolish Games</a>" / "<a href="/wiki/You_Were_Meant_for_Me_(Jewel_song)" title="You Were Meant for Me (Jewel song)">You Were Meant for Me</a>"</td>
# <td><a href="/wiki/Jewel_(singer)" title="Jewel (singer)">Jewel</a></td>
# </tr>
# <tr>
# <th scope="row">3</th>
# <td>"<a href="/wiki/I%27ll_Be_Missing_You" title="I'll Be Missing You">I'll Be Missing You</a>"</td>
# <td><a href="/wiki/Sean_Combs" title="Sean Combs">Puff Daddy</a> featuring <a href="/wiki/Faith_Evans" title="Faith Evans">Faith Evans</a> and <a href="/wiki/112_(band)" title="112 (band)">112</a></td>
# </tr>
# <tr>
# <th scope="row">4</th>
# <td>"<a href="/wiki/Un-Break_My_Heart" title="Un-Break My Heart">Un-Break My Heart</a>"</td>
# <td><a href="/wiki/Toni_Braxton" title="Toni Braxton">Toni Braxton</a></td>
# </tr>
# <tr>
# <th scope="row">5</th>
# <td>"<a href="/wiki/Can%27t_Nobody_Hold_Me_Down" title="Can't Nobody Hold Me Down">Can't Nobody Hold Me Down</a>"</td>
# <td><a href="/wiki/Sean_Combs" title="Sean Combs">Puff Daddy</a> featuring <a href="/wiki/Mase" title="Mase">Mase</a></td>
# </tr>
# <tr>
# <th scope="row">6</th>
# <td>"<a href="/wiki/I_Believe_I_Can_Fly" title="I Believe I Can Fly">I Believe I Can Fly</a>"</td>
# <td><a href="/wiki/R._Kelly" title="R. Kelly">R. Kelly</a></td>
# </tr>
# <tr>
# <th scope="row">7</th>
# <td>"<a href="/wiki/Don%27t_Let_Go_(Love)" title="Don't Let Go (Love)">Don't Let Go (Love)</a>"</td>
# <td><a href="/wiki/En_Vogue" title="En Vogue">En Vogue</a></td>
# </tr>
# <tr>
# <th scope="row">8</th>
# <td>"<a href="/wiki/Return_of_the_Mack" title="Return of the Mack">Return of the Mack</a>"</td>
# <td><a href="/wiki/Mark_Morrison" title="Mark Morrison">Mark Morrison</a></td>
# </tr>
# <tr>
# <th scope="row">9</th>
# <td>"<a href="/wiki/How_Do_I_Live" title="How Do I Live">How Do I Live</a>"</td>
# <td><a href="/wiki/LeAnn_Rimes" title="LeAnn Rimes">LeAnn Rimes</a></td>
# </tr>
# <tr>
# <th scope="row">10</th>
# <td>"<a class="mw-redirect" href="/wiki/Wannabe_(song)" title="Wannabe (song)">Wannabe</a>"</td>
# <td><a href="/wiki/Spice_Girls" title="Spice Girls">Spice Girls</a></td>
# </tr>
# <tr>
# <th scope="row">11</th>
# <td>"<a class="mw-redirect" href="/wiki/Quit_Playing_Games_(With_My_Heart)" title="Quit Playing Games (With My Heart)">Quit Playing Games (With My Heart)</a>"</td>
# <td><a href="/wiki/Backstreet_Boys" title="Backstreet Boys">Backstreet Boys</a></td>
# </tr>
# <tr>
# <th scope="row">12</th>
# <td>"<a href="/wiki/MMMBop" title="MMMBop">MMMBop</a>"</td>
# <td><a href="/wiki/Hanson_(band)" title="Hanson (band)">Hanson</a></td>
# </tr>
# <tr>
# <th scope="row">13</th>
# <td>"<a href="/wiki/For_You_I_Will_(Monica_song)" title="For You I Will (Monica song)">For You I Will</a>"</td>
# <td><a href="/wiki/Monica_(singer)" title="Monica (singer)">Monica</a></td>
# </tr>
# <tr>
# <th scope="row">14</th>
# <td>"<a href="/wiki/You_Make_Me_Wanna..." title="You Make Me Wanna...">You Make Me Wanna...</a>"</td>
# <td><a class="mw-redirect" href="/wiki/Usher_(entertainer)" title="Usher (entertainer)">Usher</a></td>
# </tr>
# <tr>
# <th scope="row">15</th>
# <td>"<a href="/wiki/Bitch_(Meredith_Brooks_song)" title="Bitch (Meredith Brooks song)">Bitch</a>"</td>
# <td><a href="/wiki/Meredith_Brooks" title="Meredith Brooks">Meredith Brooks</a></td>
# </tr>
# <tr>
# <th scope="row">16</th>
# <td>"<a href="/wiki/Nobody_(Keith_Sweat_song)" title="Nobody (Keith Sweat song)">Nobody</a>"</td>
# <td><a href="/wiki/Keith_Sweat" title="Keith Sweat">Keith Sweat</a> featuring <a href="/wiki/Athena_Cage" title="Athena Cage">Athena Cage</a></td>
# </tr>
# <tr>
# <th scope="row">17</th>
# <td>"<a href="/wiki/Semi-Charmed_Life" title="Semi-Charmed Life">Semi-Charmed Life</a>"</td>
# <td><a href="/wiki/Third_Eye_Blind" title="Third Eye Blind">Third Eye Blind</a></td>
# </tr>
# <tr>
# <th scope="row">18</th>
# <td>"<a href="/wiki/Barely_Breathing" title="Barely Breathing">Barely Breathing</a>"</td>
# <td><a href="/wiki/Duncan_Sheik" title="Duncan Sheik">Duncan Sheik</a></td>
# </tr>
# <tr>
# <th scope="row">19</th>
# <td>"<a href="/wiki/Hard_to_Say_I%27m_Sorry" title="Hard to Say I'm Sorry">Hard to Say I'm Sorry</a>"</td>
# <td><a href="/wiki/Az_Yet" title="Az Yet">Az Yet</a> featuring <a href="/wiki/Peter_Cetera" title="Peter Cetera">Peter Cetera</a></td>
# </tr>
# <tr>
# <th scope="row">20</th>
# <td>"<a href="/wiki/Mo_Money_Mo_Problems" title="Mo Money Mo Problems">Mo Money Mo Problems</a>"</td>
# <td><a href="/wiki/The_Notorious_B.I.G." title="The Notorious B.I.G.">The Notorious B.I.G.</a> featuring <a href="/wiki/Sean_Combs" title="Sean Combs">Puff Daddy</a> and <a href="/wiki/Mase" title="Mase">Mase</a></td>
# </tr>
# <tr>
# <th scope="row">21</th>
# <td>"<a href="/wiki/The_Freshmen_(song)" title="The Freshmen (song)">The Freshmen</a>"</td>
# <td><a href="/wiki/The_Verve_Pipe" title="The Verve Pipe">The Verve Pipe</a></td>
# </tr>
# <tr>
# <th scope="row">22</th>
# <td>"<a href="/wiki/I_Want_You_(Savage_Garden_song)" title="I Want You (Savage Garden song)">I Want You</a>"</td>
# <td><a href="/wiki/Savage_Garden" title="Savage Garden">Savage Garden</a></td>
# </tr>
# <tr>
# <th scope="row">23</th>
# <td>"<a href="/wiki/No_Diggity" title="No Diggity">No Diggity</a>"</td>
# <td><a href="/wiki/Blackstreet" title="Blackstreet">Blackstreet</a> featuring <a href="/wiki/Dr._Dre" title="Dr. Dre">Dr. Dre</a></td>
# </tr>
# <tr>
# <th scope="row">24</th>
# <td>"<a href="/wiki/I_Belong_to_You_(Every_Time_I_See_Your_Face)" title="I Belong to You (Every Time I See Your Face)">I Belong to You (Every Time I See Your Face)</a>"</td>
# <td><a class="mw-redirect" href="/wiki/Rome_(musician)" title="Rome (musician)">Rome</a></td>
# </tr>
# <tr>
# <th scope="row">25</th>
# <td>"<a href="/wiki/Hypnotize_(The_Notorious_B.I.G._song)" title="Hypnotize (The Notorious B.I.G. song)">Hypnotize</a>"</td>
# <td><a href="/wiki/The_Notorious_B.I.G." title="The Notorious B.I.G.">The Notorious B.I.G.</a></td>
# </tr>
# <tr>
# <th scope="row">26</th>
# <td>"<a href="/wiki/Every_Time_I_Close_My_Eyes" title="Every Time I Close My Eyes">Every Time I Close My Eyes</a>"</td>
# <td><a href="/wiki/Babyface_(musician)" title="Babyface (musician)">Babyface</a></td>
# </tr>
# <tr>
# <th scope="row">27</th>
# <td>"<a href="/wiki/In_My_Bed" title="In My Bed">In My Bed</a>"</td>
# <td><a href="/wiki/Dru_Hill" title="Dru Hill">Dru Hill</a></td>
# </tr>
# <tr>
# <th scope="row">28</th>
# <td>"<a href="/wiki/Say_You%27ll_Be_There" title="Say You'll Be There">Say You'll Be There</a>"</td>
# <td><a href="/wiki/Spice_Girls" title="Spice Girls">Spice Girls</a></td>
# </tr>
# <tr>
# <th scope="row">29</th>
# <td>"<a href="/wiki/Do_You_Know_(What_It_Takes)" title="Do You Know (What It Takes)">Do You Know (What It Takes)</a>"</td>
# <td><a href="/wiki/Robyn" title="Robyn">Robyn</a></td>
# </tr>
# <tr>
# <th scope="row">30</th>
# <td>"<a href="/wiki/4_Seasons_of_Loneliness" title="4 Seasons of Loneliness">4 Seasons of Loneliness</a>"</td>
# <td><a href="/wiki/Boyz_II_Men" title="Boyz II Men">Boyz II Men</a></td>
# </tr>
# <tr>
# <th scope="row">31</th>
# <td>"<a href="/wiki/G.H.E.T.T.O.U.T." title="G.H.E.T.T.O.U.T.">G.H.E.T.T.O.U.T.</a>"</td>
# <td><a href="/wiki/Changing_Faces_(group)" title="Changing Faces (group)">Changing Faces</a></td>
# </tr>
# <tr>
# <th scope="row">32</th>
# <td>"<a href="/wiki/Honey_(Mariah_Carey_song)" title="Honey (Mariah Carey song)">Honey</a>"</td>
# <td><a href="/wiki/Mariah_Carey" title="Mariah Carey">Mariah Carey</a></td>
# </tr>
# <tr>
# <th scope="row">33</th>
# <td>"<a href="/wiki/I_Believe_in_You_and_Me" title="I Believe in You and Me">I Believe in You and Me</a>"</td>
# <td><a href="/wiki/Whitney_Houston" title="Whitney Houston">Whitney Houston</a></td>
# </tr>
# <tr>
# <th scope="row">34</th>
# <td>"<a href="/wiki/Da%27_Dip" title="Da' Dip">Da' Dip</a>"</td>
# <td><a href="/wiki/Freak_Nasty" title="Freak Nasty">Freak Nasty</a></td>
# </tr>
# <tr>
# <th scope="row">35</th>
# <td>"<a href="/wiki/2_Become_1" title="2 Become 1">2 Become 1</a>"</td>
# <td><a href="/wiki/Spice_Girls" title="Spice Girls">Spice Girls</a></td>
# </tr>
# <tr>
# <th scope="row">36</th>
# <td>"<a href="/wiki/All_for_You_(Sister_Hazel_song)" title="All for You (Sister Hazel song)">All for You</a>"</td>
# <td><a href="/wiki/Sister_Hazel" title="Sister Hazel">Sister Hazel</a></td>
# </tr>
# <tr>
# <th scope="row">37</th>
# <td>"<a href="/wiki/Cupid_(112_song)" title="Cupid (112 song)">Cupid</a>"</td>
# <td><a href="/wiki/112_(band)" title="112 (band)">112</a></td>
# </tr>
# <tr>
# <th scope="row">38</th>
# <td>"<a href="/wiki/Where_Have_All_the_Cowboys_Gone%3F" title="Where Have All the Cowboys Gone?">Where Have All the Cowboys Gone?</a>"</td>
# <td><a href="/wiki/Paula_Cole" title="Paula Cole">Paula Cole</a></td>
# </tr>
# <tr>
# <th scope="row">39</th>
# <td>"<a href="/wiki/Sunny_Came_Home" title="Sunny Came Home">Sunny Came Home</a>"</td>
# <td><a href="/wiki/Shawn_Colvin" title="Shawn Colvin">Shawn Colvin</a></td>
# </tr>
# <tr>
# <th scope="row">40</th>
# <td>"<a href="/wiki/It%27s_Your_Love" title="It's Your Love">It's Your Love</a>"</td>
# <td><a href="/wiki/Tim_McGraw" title="Tim McGraw">Tim McGraw</a> and <a href="/wiki/Faith_Hill" title="Faith Hill">Faith Hill</a></td>
# </tr>
# <tr>
# <th scope="row">41</th>
# <td>"<a href="/wiki/Ooh_Aah..._Just_a_Little_Bit" title="Ooh Aah... Just a Little Bit">Ooh Aah... Just a Little Bit</a>"</td>
# <td><a href="/wiki/Gina_G" title="Gina G">Gina G</a></td>
# </tr>
# <tr>
# <th scope="row">42</th>
# <td>"<a href="/wiki/Mouth_(song)" title="Mouth (song)">Mouth</a>"</td>
# <td><a href="/wiki/Merril_Bainbridge" title="Merril Bainbridge">Merril Bainbridge</a></td>
# </tr>
# <tr>
# <th scope="row">43</th>
# <td>"<a class="mw-redirect" href="/wiki/All_Cried_Out_(Lisa_Lisa_%26_Cult_Jam_song)" title="All Cried Out (Lisa Lisa &amp; Cult Jam song)">All Cried Out</a>"</td>
# <td><a class="mw-redirect" href="/wiki/Allure_(group)" title="Allure (group)">Allure</a> featuring <a href="/wiki/112_(band)" title="112 (band)">112</a></td>
# </tr>
# <tr>
# <th scope="row">44</th>
# <td>"<a href="/wiki/I%27m_Still_in_Love_with_You_(New_Edition_song)" title="I'm Still in Love with You (New Edition song)">I'm Still in Love with You</a>"</td>
# <td><a href="/wiki/New_Edition" title="New Edition">New Edition</a></td>
# </tr>
# <tr>
# <th scope="row">45</th>
# <td>"<a href="/wiki/Invisible_Man_(song)" title="Invisible Man (song)">Invisible Man</a>"</td>
# <td><a href="/wiki/98_Degrees" title="98 Degrees">98 Degrees</a></td>
# </tr>
# <tr>
# <th scope="row">46</th>
# <td>"<a href="/wiki/Not_Tonight" title="Not Tonight">Not Tonight</a>"</td>
# <td><a href="/wiki/Lil%27_Kim" title="Lil' Kim">Lil' Kim</a> featuring <a href="/wiki/Da_Brat" title="Da Brat">Da Brat</a>, <a href="/wiki/Lisa_Lopes" title="Lisa Lopes">Left Eye</a>, <a href="/wiki/Missy_Elliott" title="Missy Elliott">Missy Elliott</a> and <a href="/wiki/Angie_Martinez" title="Angie Martinez">Angie Martinez</a></td>
# </tr>
# <tr>
# <th scope="row">47</th>
# <td>"<a href="/wiki/Look_into_My_Eyes_(Bone_Thugs-n-Harmony_song)" title="Look into My Eyes (Bone Thugs-n-Harmony song)">Look into My Eyes</a>"</td>
# <td><a href="/wiki/Bone_Thugs-n-Harmony" title="Bone Thugs-n-Harmony">Bone Thugs-n-Harmony</a></td>
# </tr>
# <tr>
# <th scope="row">48</th>
# <td>"<a href="/wiki/Get_It_Together_(702_song)" title="Get It Together (702 song)">Get It Together</a>"</td>
# <td><a class="mw-redirect" href="/wiki/702_(band)" title="702 (band)">702</a></td>
# </tr>
# <tr>
# <th scope="row">49</th>
# <td>"<a href="/wiki/All_by_Myself#C.C3.A9line_Dion_version" title="All by Myself">All by Myself</a>"</td>
# <td><a href="/wiki/Celine_Dion" title="Celine Dion">Celine Dion</a></td>
# </tr>
# <tr>
# <th scope="row">50</th>
# <td>"<a href="/wiki/It%27s_All_Coming_Back_to_Me_Now" title="It's All Coming Back to Me Now">It's All Coming Back to Me Now</a>"</td>
# <td><a href="/wiki/Celine_Dion" title="Celine Dion">Celine Dion</a></td>
# </tr>
# <tr>
# <th scope="row">51</th>
# <td>"<a href="/wiki/My_Love_Is_the_Shhh!" title="My Love Is the Shhh!">My Love Is the Shhh!</a>"</td>
# <td><a href="/wiki/Somethin%27_for_the_People" title="Somethin' for the People">Somethin' for the People</a> featuring <a href="/wiki/Trina_%26_Tamara" title="Trina &amp; Tamara">Trina &amp; Tamara</a></td>
# </tr>
# <tr>
# <th scope="row">52</th>
# <td>"<a class="mw-redirect" href="/wiki/Where_Do_You_Go_(No_Mercy_song)" title="Where Do You Go (No Mercy song)">Where Do You Go</a>"</td>
# <td><a href="/wiki/No_Mercy_(pop_band)" title="No Mercy (pop band)">No Mercy</a></td>
# </tr>
# <tr>
# <th scope="row">53</th>
# <td>"<a href="/wiki/I_Finally_Found_Someone" title="I Finally Found Someone">I Finally Found Someone</a>"</td>
# <td><a href="/wiki/Barbra_Streisand" title="Barbra Streisand">Barbra Streisand</a> and <a href="/wiki/Bryan_Adams" title="Bryan Adams">Bryan Adams</a></td>
# </tr>
# <tr>
# <th scope="row">54</th>
# <td>"<a class="mw-redirect" href="/wiki/I%27ll_Be_(Foxy_Brown_song)" title="I'll Be (Foxy Brown song)">I'll Be</a>"</td>
# <td><a href="/wiki/Foxy_Brown_(rapper)" title="Foxy Brown (rapper)">Foxy Brown</a> featuring <a href="/wiki/Jay-Z" title="Jay-Z">Jay-Z</a></td>
# </tr>
# <tr>
# <th scope="row">55</th>
# <td>"<a href="/wiki/If_It_Makes_You_Happy" title="If It Makes You Happy">If It Makes You Happy</a>"</td>
# <td><a href="/wiki/Sheryl_Crow" title="Sheryl Crow">Sheryl Crow</a></td>
# </tr>
# <tr>
# <th scope="row">56</th>
# <td>"<a href="/wiki/Never_Make_a_Promise" title="Never Make a Promise">Never Make a Promise</a>"</td>
# <td><a href="/wiki/Dru_Hill" title="Dru Hill">Dru Hill</a></td>
# </tr>
# <tr>
# <th scope="row">57</th>
# <td>"<a href="/wiki/When_You_Love_a_Woman" title="When You Love a Woman">When You Love a Woman</a>"</td>
# <td><a href="/wiki/Journey_(band)" title="Journey (band)">Journey</a></td>
# </tr>
# <tr>
# <th scope="row">58</th>
# <td>"<a href="/wiki/Up_Jumps_da_Boogie" title="Up Jumps da Boogie">Up Jumps da Boogie</a>"</td>
# <td><a href="/wiki/Timbaland_%26_Magoo" title="Timbaland &amp; Magoo">Timbaland &amp; Magoo</a> featuring <a href="/wiki/Missy_Elliott" title="Missy Elliott">Missy Elliott</a> and <a href="/wiki/Aaliyah" title="Aaliyah">Aaliyah</a></td>
# </tr>
# <tr>
# <th scope="row">59</th>
# <td>"<a href="/wiki/I_Don%27t_Want_To" title="I Don't Want To">I Don't Want To</a>" / "<a href="/wiki/I_Love_Me_Some_Him" title="I Love Me Some Him">I Love Me Some Him</a>"</td>
# <td><a href="/wiki/Toni_Braxton" title="Toni Braxton">Toni Braxton</a></td>
# </tr>
# <tr>
# <th scope="row">60</th>
# <td>"<a href="/wiki/Everyday_Is_a_Winding_Road" title="Everyday Is a Winding Road">Everyday Is a Winding Road</a>"</td>
# <td><a href="/wiki/Sheryl_Crow" title="Sheryl Crow">Sheryl Crow</a></td>
# </tr>
# <tr>
# <th scope="row">61</th>
# <td>"<a href="/wiki/Cold_Rock_a_Party" title="Cold Rock a Party">Cold Rock a Party</a>"</td>
# <td><a href="/wiki/MC_Lyte" title="MC Lyte">MC Lyte</a></td>
# </tr>
# <tr>
# <th scope="row">62</th>
# <td>"<a href="/wiki/Pony_(Ginuwine_song)" title="Pony (Ginuwine song)">Pony</a>"</td>
# <td><a href="/wiki/Ginuwine" title="Ginuwine">Ginuwine</a></td>
# </tr>
# <tr>
# <th scope="row">63</th>
# <td>"<a href="/wiki/Building_a_Mystery" title="Building a Mystery">Building a Mystery</a>"</td>
# <td><a href="/wiki/Sarah_McLachlan" title="Sarah McLachlan">Sarah McLachlan</a></td>
# </tr>
# <tr>
# <th scope="row">64</th>
# <td>"<a href="/wiki/I_Love_You_Always_Forever" title="I Love You Always Forever">I Love You Always Forever</a>"</td>
# <td><a href="/wiki/Donna_Lewis" title="Donna Lewis">Donna Lewis</a></td>
# </tr>
# <tr>
# <th scope="row">65</th>
# <td>"<a href="/wiki/Your_Woman" title="Your Woman">Your Woman</a>"</td>
# <td><a href="/wiki/White_Town" title="White Town">White Town</a></td>
# </tr>
# <tr>
# <th scope="row">66</th>
# <td>"<a href="/wiki/C_U_When_U_Get_There" title="C U When U Get There">C U When U Get There</a>"</td>
# <td><a href="/wiki/Coolio" title="Coolio">Coolio</a> featuring 40 Thevz</td>
# </tr>
# <tr>
# <th scope="row">67</th>
# <td>"<a href="/wiki/Change_the_World" title="Change the World">Change the World</a>"</td>
# <td><a href="/wiki/Eric_Clapton" title="Eric Clapton">Eric Clapton</a></td>
# </tr>
# <tr>
# <th scope="row">68</th>
# <td>"<a href="/wiki/My_Baby_Daddy" title="My Baby Daddy">My Baby Daddy</a>"</td>
# <td><a href="/wiki/B-Rock_and_the_Bizz" title="B-Rock and the Bizz">B-Rock and the Bizz</a></td>
# </tr>
# <tr>
# <th scope="row">69</th>
# <td>"<a href="/wiki/Tubthumping" title="Tubthumping">Tubthumping</a>"</td>
# <td><a href="/wiki/Chumbawamba" title="Chumbawamba">Chumbawamba</a></td>
# </tr>
# <tr>
# <th scope="row">70</th>
# <td>"<a href="/wiki/Gotham_City_(song)" title="Gotham City (song)">Gotham City</a>"</td>
# <td><a href="/wiki/R._Kelly" title="R. Kelly">R. Kelly</a></td>
# </tr>
# <tr>
# <th scope="row">71</th>
# <td>"<a href="/wiki/Last_Night_(Az_Yet_song)" title="Last Night (Az Yet song)">Last Night</a>"</td>
# <td><a href="/wiki/Az_Yet" title="Az Yet">Az Yet</a></td>
# </tr>
# <tr>
# <th scope="row">72</th>
# <td>"<a href="/wiki/Jock_Jam" title="Jock Jam">The Jock Jam</a>"</td>
# <td>Various Artists</td>
# </tr>
# <tr>
# <th scope="row">73</th>
# <td>"<a href="/wiki/Big_Daddy_(song)" title="Big Daddy (song)">Big Daddy</a>"</td>
# <td><a href="/wiki/Heavy_D" title="Heavy D">Heavy D</a></td>
# </tr>
# <tr>
# <th scope="row">74</th>
# <td>"<a href="/wiki/What_About_Us%3F_(Total_song)" title="What About Us? (Total song)">What About Us</a>"</td>
# <td><a class="mw-redirect" href="/wiki/Total_(band)" title="Total (band)">Total</a></td>
# </tr>
# <tr>
# <th scope="row">75</th>
# <td>"<a href="/wiki/Smile_(Scarface_song)" title="Smile (Scarface song)">Smile</a>"</td>
# <td><a href="/wiki/Scarface_(rapper)" title="Scarface (rapper)">Scarface</a> featuring <a href="/wiki/Tupac_Shakur" title="Tupac Shakur">2Pac</a> and Johnny P.</td>
# </tr>
# <tr>
# <th scope="row">76</th>
# <td>"<a href="/wiki/What%27s_on_Tonight" title="What's on Tonight">What's on Tonight</a>"</td>
# <td><a href="/wiki/Montell_Jordan" title="Montell Jordan">Montell Jordan</a></td>
# </tr>
# <tr>
# <th scope="row">77</th>
# <td>"<a href="/wiki/Secret_Garden_(Bruce_Springsteen_song)" title="Secret Garden (Bruce Springsteen song)">Secret Garden</a>"</td>
# <td><a href="/wiki/Bruce_Springsteen" title="Bruce Springsteen">Bruce Springsteen</a></td>
# </tr>
# <tr>
# <th scope="row">78</th>
# <td>"<a href="/wiki/The_One_I_Gave_My_Heart_To" title="The One I Gave My Heart To">The One I Gave My Heart To</a>"</td>
# <td><a href="/wiki/Aaliyah" title="Aaliyah">Aaliyah</a></td>
# </tr>
# <tr>
# <th scope="row">79</th>
# <td>"<a href="/wiki/Fly_Like_an_Eagle_(song)#Cover_versions" title="Fly Like an Eagle (song)">Fly Like an Eagle</a>"</td>
# <td><a href="/wiki/Seal_(musician)" title="Seal (musician)">Seal</a></td>
# </tr>
# <tr>
# <th scope="row">80</th>
# <td>"<a href="/wiki/No_Time_(Lil%27_Kim_song)" title="No Time (Lil' Kim song)">No Time</a>"</td>
# <td><a href="/wiki/Lil%27_Kim" title="Lil' Kim">Lil' Kim</a> featuring <a href="/wiki/Sean_Combs" title="Sean Combs">Puff Daddy</a></td>
# </tr>
# <tr>
# <th scope="row">81</th>
# <td>"<a class="mw-redirect" href="/wiki/Naked_Eye_(song)" title="Naked Eye (song)">Naked Eye</a>"</td>
# <td><a href="/wiki/Luscious_Jackson" title="Luscious Jackson">Luscious Jackson</a></td>
# </tr>
# <tr>
# <th scope="row">82</th>
# <td>"<a href="/wiki/Macarena_(song)" title="Macarena (song)">Macarena</a> (Bayside Boys Mix)"</td>
# <td><a href="/wiki/Los_del_R%C3%ADo" title="Los del Río">Los del Río</a></td>
# </tr>
# <tr>
# <th scope="row">83</th>
# <td>"<a href="/wiki/On_%26_On_(Erykah_Badu_song)" title="On &amp; On (Erykah Badu song)">On &amp; On</a>"</td>
# <td><a href="/wiki/Erykah_Badu" title="Erykah Badu">Erykah Badu</a></td>
# </tr>
# <tr>
# <th scope="row">84</th>
# <td>"Don't Wanna Be a Player"</td>
# <td><a href="/wiki/Joe_(singer)" title="Joe (singer)">Joe</a></td>
# </tr>
# <tr>
# <th scope="row">85</th>
# <td>"<a class="mw-redirect" href="/wiki/I_Shot_the_Sheriff_(Warren_G_song)" title="I Shot the Sheriff (Warren G song)">I Shot the Sheriff</a>"</td>
# <td><a href="/wiki/Warren_G" title="Warren G">Warren G</a></td>
# </tr>
# <tr>
# <th scope="row">86</th>
# <td>"<a href="/wiki/You_Should_Be_Mine_(Don%27t_Waste_Your_Time)" title="You Should Be Mine (Don't Waste Your Time)">You Should Be Mine (Don't Waste Your Time)</a>"</td>
# <td><a href="/wiki/Brian_McKnight" title="Brian McKnight">Brian McKnight</a> featuring <a href="/wiki/Mase" title="Mase">Mase</a></td>
# </tr>
# <tr>
# <th scope="row">87</th>
# <td>"<a href="/wiki/Don%27t_Cry_for_Me_Argentina" title="Don't Cry for Me Argentina">Don't Cry for Me Argentina</a>"</td>
# <td><a href="/wiki/Madonna_(entertainer)" title="Madonna (entertainer)">Madonna</a></td>
# </tr>
# <tr>
# <th scope="row">88</th>
# <td>"Someone"</td>
# <td><a href="/wiki/SWV" title="SWV">SWV</a> and <a href="/wiki/Sean_Combs" title="Sean Combs">Puff Daddy</a></td>
# </tr>
# <tr>
# <th scope="row">89</th>
# <td>"<a href="/wiki/Go_the_Distance" title="Go the Distance">Go the Distance</a>"</td>
# <td><a href="/wiki/Michael_Bolton" title="Michael Bolton">Michael Bolton</a></td>
# </tr>
# <tr>
# <th scope="row">90</th>
# <td>"<a href="/wiki/One_More_Time_(Real_McCoy_song)" title="One More Time (Real McCoy song)">One More Time</a>"</td>
# <td><a href="/wiki/Real_McCoy_(band)" title="Real McCoy (band)">Real McCoy</a></td>
# </tr>
# <tr>
# <th scope="row">91</th>
# <td>"Butta Love"</td>
# <td><a class="mw-redirect" href="/wiki/Next_(group)" title="Next (group)">Next</a></td>
# </tr>
# <tr>
# <th scope="row">92</th>
# <td>"<a class="mw-redirect" href="/wiki/Coco_Jambo" title="Coco Jambo">Coco Jambo</a>"</td>
# <td><a href="/wiki/Mr._President_(band)" title="Mr. President (band)">Mr. President</a></td>
# </tr>
# <tr>
# <th scope="row">93</th>
# <td>"<a href="/wiki/Twisted_(Keith_Sweat_song)" title="Twisted (Keith Sweat song)">Twisted</a>"</td>
# <td><a href="/wiki/Keith_Sweat" title="Keith Sweat">Keith Sweat</a></td>
# </tr>
# <tr>
# <th scope="row">94</th>
# <td>"<a href="/wiki/Barbie_Girl" title="Barbie Girl">Barbie Girl</a>"</td>
# <td><a href="/wiki/Aqua_(band)" title="Aqua (band)">Aqua</a></td>
# </tr>
# <tr>
# <th scope="row">95</th>
# <td>"<a href="/wiki/When_You%27re_Gone_(The_Cranberries_song)" title="When You're Gone (The Cranberries song)">When You're Gone</a>" / "<a href="/wiki/Free_to_Decide" title="Free to Decide">Free to Decide</a>"</td>
# <td><a href="/wiki/The_Cranberries" title="The Cranberries">The Cranberries</a></td>
# </tr>
# <tr>
# <th scope="row">96</th>
# <td>"<a href="/wiki/Let_Me_Clear_My_Throat" title="Let Me Clear My Throat">Let Me Clear My Throat</a>"</td>
# <td><a href="/wiki/DJ_Kool" title="DJ Kool">DJ Kool</a></td>
# </tr>
# <tr>
# <th scope="row">97</th>
# <td>"<a href="/wiki/I_Like_It_Like_That_(Pete_Rodriguez_song)#The_Blackout_All-Stars_version" title="I Like It Like That (Pete Rodriguez song)">I Like It</a>"</td>
# <td><a href="/wiki/The_Blackout_All-Stars" title="The Blackout All-Stars">The Blackout All-Stars</a></td>
# </tr>
# <tr>
# <th scope="row">98</th>
# <td>"<a href="/wiki/You%27re_Makin%27_Me_High" title="You're Makin' Me High">You're Makin' Me High</a>" / "<a href="/wiki/Let_It_Flow_(song)" title="Let It Flow (song)">Let It Flow</a>"</td>
# <td><a href="/wiki/Toni_Braxton" title="Toni Braxton">Toni Braxton</a></td>
# </tr>
# <tr>
# <th scope="row">99</th>
# <td>"<a href="/wiki/You_Must_Love_Me" title="You Must Love Me">You Must Love Me</a>"</td>
# <td><a href="/wiki/Madonna_(entertainer)" title="Madonna (entertainer)">Madonna</a></td>
# </tr>
# <tr>
# <th scope="row">100</th>
# <td>"<a href="/wiki/Let_It_Go_(Ray_J_song)" title="Let It Go (Ray J song)">Let It Go</a>"</td>
# <td><a href="/wiki/Ray_J" title="Ray J">Ray J</a></td>
# </tr>
# </table>

# %%
trs1 = table.find_all('tr')
tds1 = trs1[2].find_all('td')
print(tds1[0].find('a'))
#tds1[0].find('a')['href']
[i['href'] for i in tds1[0].find_all('a')]
#tds1[0]
#[i.text for i in tds1[0].find_all('a')]
# Out:
# <a href="/wiki/Foolish_Games" title="Foolish Games">Foolish Games</a>
# ['/wiki/Foolish_Games', '/wiki/You_Were_Meant_for_Me_(Jewel_song)']

# %%
songs = []
trs = table.find_all('tr')
for i in range(1, 101):
    #print(i)
    tds = trs[i].find_all('td')
    singer = [i.text for i in tds[1].find_all('a')]
    song = [i.text for i in tds[0].find_all('a')]
    songurl = [i['href'] for i in tds[0].find_all('a')]
    urls = tds[1].prettify().split('"')
    url = [url_str for url_str in urls if 'wiki' in url_str]
    #print(trs[i].find('th'))
    dict = {'band_singer':singer, 'ranking':trs[i].find('th').text, 'song':song, 'songurl':songurl, 'titletext':tds[0].text, 
            'url':url}
    songs.append(dict)

# %%
songs[:4]
# Out:
# [{'band_singer': ['Elton John'],
#   'ranking': '1',
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '"Something About the Way You Look Tonight" / "Candle in the Wind 1997"',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': '2',
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '"Foolish Games" / "You Were Meant for Me"',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': '3',
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '"I\'ll Be Missing You"',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': '4',
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '"Un-Break My Heart"',
#   'url': ['/wiki/Toni_Braxton']}]

# %% [markdown]
# You should get something similar to this (where songs is the aforementioned list):
#
# ```
# songs[2:4]
# ```
#
# ```
# [{'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'title': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'}]
# ```

# %% [markdown]
# #### 1.2 Generalize the previous: scrape Wikipedia from 1992 to 2014

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. (We choose these later years rather than 1970 as you might find music from this era more interesting.) Download these using Python's `requests` module and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second (look up `time.sleep` in Python) at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %% [markdown]
# *HINT: you might find `range` and string-interpolation useful to construct the URLs *.

# %%
#scraping the wab
import requests
import time
years_reqs = []
for i in range(1994, 2015): #range是左闭右开的
    time.sleep(5)
    url = "https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_"+str(i)
    years_reqs.append(requests.get(url))
    #yearstext[str(i)] = years_reqs[i-1994].text
    print("page in %dyear is geted" %i)
# Out:
# page in 1994year is geted
# page in 1995year is geted
# page in 1996year is geted
# page in 1997year is geted
# page in 1998year is geted
# page in 1999year is geted
# page in 2000year is geted
# page in 2001year is geted
# page in 2002year is geted
# page in 2003year is geted
# page in 2004year is geted
# page in 2005year is geted
# page in 2006year is geted
# page in 2007year is geted
# page in 2008year is geted
# page in 2009year is geted
# page in 2010year is geted
# page in 2011year is geted
# page in 2012year is geted
# page in 2013year is geted
# page in 2014year is geted

# %%
yearstext = {}
for i in range(1994, 2015):
    yearstext[str(i)] = years_reqs[i-1994].text

# %%
from IPython.display import HTML
HTML(yearstext['2011'])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Billboard Year-End Hot 100 singles of 2011 - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2011","wgTitle":"Billboard Year-End Hot 100 singles of 2011","wgCurRevisionId":795431535,"wgRevisionId":795431535,"wgArticleId":34003303,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["2011 record charts","Billboard charts"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Billboard_Year-End_Hot_100_singles_of_2011","wgRelevantArticleId":34003303,"wgRequestId":"WfEUEgpAIDgAAGjXzz4AAABX","wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":false,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFExpandAllSectionsUserOption":false,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikibaseItemId":"Q4270383","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":false,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","skins.vector.styles.experimental.print":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/
#
# });mw.loader.load(["ext.cite.a11y","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cskins.vector.styles.experimental.print%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.gadget.charinsert-styles&amp;only=styles&amp;skin=vector"/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.31.0-wmf.4"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/c/c2/Adele_-_Seattle%2C_WA_-_8.12.2011.jpg"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2011"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Billboard_Year-End_Hot_100_singles_of_2011&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Billboard_Year-End_Hot_100_singles_of_2011&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="license" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2011"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# <!--[if lt IE 9]><script src="/w/load.php?debug=false&amp;lang=en&amp;modules=html5shiv&amp;only=scripts&amp;skin=vector&amp;sync=1"></script><![endif]-->
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Billboard_Year-End_Hot_100_singles_of_2011 rootpage-Billboard_Year-End_Hot_100_singles_of_2011 vector-experimental-print-styles vector-nav-directionality skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice" class="mw-body-content"><!-- CentralNotice --></div>
# 						<div class="mw-indicators mw-body-content">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en"><i>Billboard</i> Year-End Hot 100 singles of 2011</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub" class="noprint">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><div class="mw-parser-output"><div class="thumb tright">
# <div class="thumbinner" style="width:192px;"><a href="/wiki/File:Adele_-_Seattle,_WA_-_8.12.2011.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/comm

# %% [markdown]
# #### 1.3 Parse and Clean data

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single.  Now write a function `parse_year(the_year, yeartext_dict)` which takes the year, prints it out, gets the text for the year from the just created `yearstext` dictionary, and return a list of dictionaries for that year, with one dictionary for each single. Store this list in the variable `yearinfo`.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %%
def parse_year(the_year, yeartext_dict):
    soup = BeautifulSoup(yeartext_dict[str(the_year)], 'html.parser')
    table = soup.find(class_ = 'wikitable')
    yearinfo = []
    trs = table.find_all('tr')
    for i in range(1, 101):
        tds = trs[i].find_all('td')
        singer = [i.text for i in tds[1].find_all('a')]
        song = [i.text for i in tds[0].find_all('a')]
        songurl = [i['href'] for i in tds[0].find_all('a')]
        urls = tds[1].prettify().split('"')
        singerurl = [url_str for url_str in urls if 'wiki' in url_str]
        dict = {'band_singer':singer, 'ranking':int(trs[i].find('th').text), 'song':song, 'songurl':songurl, 
                'titletext':tds[0].text, 'url':singerurl}
        yearinfo.append(dict)
    return yearinfo

# %% [markdown]
# The spec of this function is provided below:

# %%
"""
Function
--------
parse_year

Inputs
------
the_year: the year you want the singles for
yeartext_dict: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    

Notes
-----
See description and example above.
"""

# %% [markdown]
# #### Helpful notes
#
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some singles don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# Thus there are some issues this function must handle:
#
# 1. There can be more than one  `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be two songs in a single, because of the way the industry works: there are two-sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for an example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that Wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %% [markdown]
# As a check, we can do this for 1997. We'll print the first 5 outputs: `parse_year(1997, yearstext)[:5]`

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %%
parse_year(1997, yearstext)[:5]
# Out:
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '"Something About the Way You Look Tonight" / "Candle in the Wind 1997"',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '"Foolish Games" / "You Were Meant for Me"',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '"I\'ll Be Missing You"',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '"Un-Break My Heart"',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '"Can\'t Nobody Hold Me Down"',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]

# %% [markdown]
# ```
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]
# ```

# %%
#测试用cell
from bs4 import BeautifulSoup
soup = BeautifulSoup(yearstext['1997'], 'html.parser')
table = soup.find(class_ = 'wikitable')
trs1=table.find_all('tr')
tds1 = trs1[1].find_all('td')
tds1[0].find('a')['href']
# Out:
# '/wiki/Something_About_the_Way_You_Look_Tonight'

# %%
#清理数据：有别名的歌曲只保留第一个，多个歌手的拆开成多行,没有歌曲链接的设置songurl=None，歌名为titletext，
def new_parse_year(the_year, yeartext_dict):
    soup = BeautifulSoup(yeartext_dict[str(the_year)], 'html.parser')
    table = soup.find(class_ = 'wikitable')
    yearinfo = []
    trs = table.find_all('tr')
    for i in range(1, 101):
        tds = trs[i].find_all('td')
        if tds[0].find('a') == None: #没有歌曲链接
            song_text = tds[0].text.split('/')[0]
            songurl = None
        else:
            song_text = tds[0].text.split('/')[0]
            songurl = tds[0].find('a')['href']
        singer = [i.text for i in tds[1].find_all('a')]
        urls = tds[1].prettify().split('"')
        singersurl = [url_str for url_str in urls if 'wiki' in url_str]
        for singer_num in range(len(singer)):
            dict = {'band_singer':singer[singer_num], 'ranking':int(trs[i].find('th').text), 'song':song_text, 'songurl':songurl, 
                    'titletext':tds[0].text, 'url':singersurl[singer_num]}
            yearinfo.append(dict)
    return yearinfo

# %%
new_parse_year(1997, yearstext)[:5]
# Out:
# [{'band_singer': 'Elton John',
#   'ranking': 1,
#   'song': '"Something About the Way You Look Tonight" ',
#   'songurl': '/wiki/Something_About_the_Way_You_Look_Tonight',
#   'titletext': '"Something About the Way You Look Tonight" / "Candle in the Wind 1997"',
#   'url': '/wiki/Elton_John'},
#  {'band_singer': 'Jewel',
#   'ranking': 2,
#   'song': '"Foolish Games" ',
#   'songurl': '/wiki/Foolish_Games',
#   'titletext': '"Foolish Games" / "You Were Meant for Me"',
#   'url': '/wiki/Jewel_(singer)'},
#  {'band_singer': 'Puff Daddy',
#   'ranking': 3,
#   'song': '"I\'ll Be Missing You"',
#   'songurl': '/wiki/I%27ll_Be_Missing_You',
#   'titletext': '"I\'ll Be Missing You"',
#   'url': '/wiki/Sean_Combs'},
#  {'band_singer': 'Faith Evans',
#   'ranking': 3,
#   'song': '"I\'ll Be Missing You"',
#   'songurl': '/wiki/I%27ll_Be_Missing_You',
#   'titletext': '"I\'ll Be Missing You"',
#   'url': '/wiki/Faith_Evans'},
#  {'band_singer': '112',
#   'ranking': 3,
#   'song': '"I\'ll Be Missing You"',
#   'songurl': '/wiki/I%27ll_Be_Missing_You',
#   'titletext': '"I\'ll Be Missing You"',
#   'url': '/wiki/112_(band)'}]

# %%
#把年份放进字典里
yearinfo = []
for i in range(1994, 2015):
    the_yearinfo = new_parse_year(i, yearstext)
    for j in the_yearinfo:
        j['year'] = int(i)
    yearinfo = yearinfo+the_yearinfo

# %%
yearinfo[:5]
# Out:
# [{'band_singer': 'Ace of Base',
#   'ranking': 1,
#   'song': '"The Sign"',
#   'songurl': '/wiki/The_Sign_(song)',
#   'titletext': '"The Sign"',
#   'url': '/wiki/Ace_of_Base',
#   'year': 1994},
#  {'band_singer': 'All-4-One',
#   'ranking': 2,
#   'song': '"I Swear"',
#   'songurl': '/wiki/I_Swear#All-4-One_version',
#   'titletext': '"I Swear"',
#   'url': '/wiki/All-4-One',
#   'year': 1994},
#  {'band_singer': 'Boyz II Men',
#   'ranking': 3,
#   'song': '"I\'ll Make Love to You"',
#   'songurl': '/wiki/I%27ll_Make_Love_to_You',
#   'titletext': '"I\'ll Make Love to You"',
#   'url': '/wiki/Boyz_II_Men',
#   'year': 1994},
#  {'band_singer': 'Céline Dion',
#   'ranking': 4,
#   'song': '"The Power of Love"',
#   'songurl': '/wiki/The_Power_of_Love_(Jennifer_Rush_song)#C.C3.A9line_Dion_version',
#   'titletext': '"The Power of Love"',
#   'url': '/wiki/C%C3%A9line_Dion',
#   'year': 1994},
#  {'band_singer': 'Mariah Carey',
#   'ranking': 5,
#   'song': '"Hero"',
#   'songurl': '/wiki/Hero_(Mariah_Carey_song)',
#   'titletext': '"Hero"',
#   'url': '/wiki/Mariah_Carey',
#   'year': 1994}]

# %% [markdown]
# #### Save a json file of information from the scraped files

# %% [markdown]
# We do not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run from here, you don't need to redo all these requests and parsing.
#
# DO NOT RERUN THE HTTP REQUESTS TO WIKIPEDIA WHEN SUBMITTING.
#
# *We **DO NOT** need to see these JSON files in your submission!*

# %%
import json

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
fd = open("data/yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()
del yearinfo

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %%
# RERUN WHEN SUBMITTING
# Another way to deal with files. Has the advantage of closing the file for you.
with open("data/yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %% [markdown]
# #### 1.4 Construct a year-song-singer dataframe from the yearly information

# %% [markdown]
# Let's construct a dataframe `flatframe` from the `yearinfo`. The frame should be similar to the frame below.  Each row of the frame represents a song, and carries with it the chief properties of year, song, singer, and ranking.
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC1.png)

# %% [markdown]
# To construct the dataframe, we'll need to iterate over the years and the singles per year. Notice how, above, the dataframe is ordered by ranking and then year. While the exact order is up to you, note that you will have to come up with a scheme to order the information.
#
# Check that the dataframe has sensible data types. You will also likely find that the year field has become an "object" (Pandas treats strings as generic objects): this is due to the conversion to and back from JSON. Such conversions need special care. Fix any data type issues with `flatframe`. (See Pandas [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function.)
# We will use this `flatframe` in the next question.
#
# (As an aside, we used the name `flatframe` to indicate that this dataframe is flattened from a hierarchical dictionary structure with the keys being the years.)

# %%
flatframe = pd.DataFrame(yearinfo, columns=['year', 'band_singer', 'ranking', 'song', 'songurl', 'url'])
flatframe
# Out:
#       year                 band_singer  ranking                                    song                                            songurl                              url
# 0     1994                 Ace of Base        1                              "The Sign"                              /wiki/The_Sign_(song)                /wiki/Ace_of_Base
# 1     1994                   All-4-One        2                               "I Swear"                    /wiki/I_Swear#All-4-One_version                  /wiki/All-4-One
# 2     1994                 Boyz II Men        3                 "I'll Make Love to You"                      /wiki/I%27ll_Make_Love_to_You                /wiki/Boyz_II_Men
# 3     1994                 Céline Dion        4                     "The Power of Love"  /wiki/The_Power_of_Love_(Jennifer_Rush_song)#C...           /wiki/C%C3%A9line_Dion
# 4     1994                Mariah Carey        5                                  "Hero"                     /wiki/Hero_(Mariah_Carey_song)               /wiki/Mariah_Carey
# 5     1994  Lisa Loeb and Nine Stories        6                   "Stay (I Missed You)"                          /wiki/Stay_(I_Missed_You)                  /wiki/Lisa_Loeb
# 6     1994                Toni Braxton        7                         "Breathe Again"                                /wiki/Breathe_Again               /wiki/Toni_Braxton
# 7     1994                 Bryan Adams        8                          "All for Love"                          /wiki/All_for_Love_(song)                /wiki/Bryan_Adams
# 8     1994                 Rod Stewart        8                          "All for Love"                          /wiki/All_for_Love_(song)                /wiki/Rod_Stewart
# 9     1994                       Sting        8                          "All for Love"                          /wiki/All_for_Love_(song)           /wiki/Sting_(musician)
# 10    1994                 Ace of Base        9                    "All That She Wants"                           /wiki/All_That_She_Wants                /wiki/Ace_of_Base
# 11    1994                 Ace of Base       10                     "Don't Turn Around"                          /wiki/Don%27t_Turn_Around                /wiki/Ace_of_Base
# 12    1994                    R. Kelly       11                         "Bump n' Grind"              /wiki/Bump_n%27_Grind_(R._Kelly_song)                   /wiki/R._Kelly
# 13    1994               Janet Jackson       12                                 "Again"                   /wiki/Again_(Janet_Jackson_song)              /wiki/Janet_Jackson
# 14    1994                     Madonna       13                         "I'll Remember"                              /wiki/I%27ll_Remember      /wiki/Madonna_(entertainer)
# 15    1994                 Salt-n-Pepa       14                            "Whatta Man"                                   /wiki/Whatta_Man                /wiki/Salt-n-Pepa
# 16    1994                    En Vogue       14                            "Whatta Man"                                   /wiki/Whatta_Man                   /wiki/En_Vogue
# 17    1994             John Mellencamp       15                            "Wild Night"                                   /wiki/Wild_Night            /wiki/John_Mellencamp
# 18    1994         Meshell Ndegeocello       15                            "Wild Night"                                   /wiki/Wild_Night        /wiki/Meshell_Ndegeocello
# 19    1994                Mariah Carey       16                          "Without You"   /wiki/Without_You_(Badfinger_song)#Mariah_Care...               /wiki/Mariah_Carey
# 20    1994                Toni Braxton       17              "You Mean the World to Me"                     /wiki/You_Mean_the_World_to_Me               /wiki/Toni_Braxton
# 21    1994                  Elton John       18         "Can You Feel the Love Tonight"                /wiki/Can_You_Feel_the_Love_Tonight                 /wiki/Elton_John
# 22    1994                      Prince       19  "The Most Beautiful Girl in the World"  /wiki/The_Most_Beautiful_Girl_in_the_World_(Pr...          /wiki/Prince_(musician)
# 23    1994                      Coolio       20                      "Fantastic Voyage"               /wiki/Fantastic_Voyage_(Coolio_song)                     /wiki/Coolio
# 24    1994                Big Mountain       21                 "Baby, I Love Your Way"                        /wiki/Baby,_I_Love_Your_Way        /wiki/Big_Mountain_(band)
# 25    1994                    Warren G       22                              "Regulate"                              /wiki/Regulate_(song)                   /wiki/Warren_G
# 26    1994                   Nate Dogg       22                              "Regulate"                              /wiki/Regulate_(song)                  /wiki/Nate_Dogg
# 27    1994                  Jon Secada       23                             "If You Go"                             /wiki/If_You_Go_(song)                 /wiki/Jon_Secada
# 28    1994                     Aaliyah       24                          "Back & Forth"                /wiki/Back_%26_Forth_(Aaliyah_song)                    /wiki/Aaliyah
# 29    1994                Richard Marx       25                       "Now and Forever"          /wiki/Now_and_Forever_(Richard_Marx_song)               /wiki/Richard_Marx
# ...    ...                         ...      ...                                     ...                                                ...                              ...
# 2745  2014           Pharrell Williams       83                         "Blurred Lines"                                /wiki/Blurred_Lines          /wiki/Pharrell_Williams
# 2746  2014                   Lady Gaga       84                        "Do What U Want"                               /wiki/Do_What_U_Want                  /wiki/Lady_Gaga
# 2747  2014                    R. Kelly       84                        "Do What U Want"                               /wiki/Do_What_U_Want                   /wiki/R._Kelly
# 2748  2014                     Shakira       85          "Can't Remember to Forget You"               /wiki/Can%27t_Remember_to_Forget_You                    /wiki/Shakira
# 2749  2014                     Rihanna       85          "Can't Remember to Forget You"               /wiki/Can%27t_Remember_to_Forget_You                    /wiki/Rihanna
# 2750  2014         5 Seconds of Summer       86                               "Amnesia"           /wiki/Amnesia_(5_Seconds_of_Summer_song)        /wiki/5_Seconds_of_Summer
# 2751  2014                        T.I.       87                           "No Mediocre"                                  /wiki/No_Mediocre                       /wiki/T.I.
# 2752  2014                 Iggy Azalea       87                           "No Mediocre"                                  /wiki/No_Mediocre                /wiki/Iggy_Azalea
# 2753  2014                      KONGOS       88                      "Come with Me Now"                             /wiki/Come_with_Me_Now              /wiki/Kongos_(band)
# 2754  2014                   Lil Wayne       89                            "Believe Me"                  /wiki/Believe_Me_(Lil_Wayne_song)                  /wiki/Lil_Wayne
# 2755  2014                       Drake       89                            "Believe Me"                  /wiki/Believe_Me_(Lil_Wayne_song)             /wiki/Drake_(rapper)
# 2756  2014           Mike WiLL Made-It       90                                    "23"                                    /wiki/23_(song)          /wiki/Mike_WiLL_Made-It
# 2757  2014                 Miley Cyrus       90                                    "23"                                    /wiki/23_(song)                /wiki/Miley_Cyrus
# 2758  2014                 Wiz Khalifa       90                                    "23"                                    /wiki/23_(song)                /wiki/Wiz_Khalifa
# 2759  2014                     Juicy J       90                                    "23"                                    /wiki/23_(song)                    /wiki/Juicy_J
# 2760  2014                   Jake Owen       91                              "Beachin'"                                   /wiki/Beachin%27                  /wiki/Jake_Owen
# 2761  2014     Macklemore & Ryan Lewis       92                           "White Walls"                                  /wiki/White_Walls  /wiki/Macklemore_%26_Ryan_Lewis
# 2762  2014                 ScHoolboy Q       92                           "White Walls"                                  /wiki/White_Walls                /wiki/ScHoolboy_Q
# 2763  2014                      Hollis       92                           "White Walls"                                  /wiki/White_Walls            /wiki/Hollis_(singer)
# 2764  2014         5 Seconds of Summer       93                  "She Looks So Perfect"                         /wiki/She_Looks_So_Perfect        /wiki/5_Seconds_of_Summer
# 2765  2014                        Zedd       94                        "Stay the Night"                   /wiki/Stay_the_Night_(Zedd_song)            /wiki/Zedd_(musician)
# 2766  2014             Hayley Williams       94                        "Stay the Night"                   /wiki/Stay_the_Night_(Zedd_song)            /wiki/Hayley_Williams
# 2767  2014                     Beyoncé       95                             "Partition"                             /wiki/Partition_(song)               /wiki/Beyonc%C3%A9
# 2768  2014                 ScHoolboy Q       96                                "Studio"                                /wiki/Studio_(song)                /wiki/ScHoolboy_Q
# 2769  2014          BJ the Chicago Kid       96                                "Studio"                                /wiki/Studio_(song)         /wiki/BJ_the_Chicago_Kid
# 2770  2014                       Drake       97                              "0 to 100                       /wiki/0_to_100_/_The_Catch_Up             /wiki/Drake_(rapper)
# 2771  2014                   Lee Brice       98                         "I Don't Dance"             /wiki/I_Don%27t_Dance_(Lee_Brice_song)                  /wiki/Lee_Brice
# 2772  2014             Miranda Lambert       99                         "Somethin' Bad"                              /wiki/Somethin%27_Bad            /wiki/Miranda_Lambert
# 2773  2014            Carrie Underwood       99                         "Somethin' Bad"                              /wiki/Somethin%27_Bad           /wiki/Carrie_Underwood
# 2774  2014                 Miley Cyrus      100                             "Adore You"                                    /wiki/Adore_You                /wiki/Miley_Cyrus
#
# [2775 rows x 6 columns]

# %%
flatframe.dtypes
# Out:
# year            int64
# band_singer    object
# ranking         int64
# song           object
# songurl        object
# url            object
# dtype: object

# %% [markdown]
# ### Who are the highest quality singers?

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# #### 1.5 Find highest quality singers according to how prolific they are
#
# What do we mean by highest quality? This is of course open to interpretation, but let's define "highest quality" **here as the number of times a singer appears in the top 100 over this time period. **If a singer appears twice in a year (for different songs), this is counted as two appearances, not one.
#
# Make a bar-plot of the most prolific singers. Singers on this chart should have appeared at-least more than 15 times. (HINT: look at the docs for the pandas method `value_counts`.)

# %%
hq_singers = pd.value_counts(flatframe['band_singer'])

# %%
hq_singers[hq_singers>15].plot(kind='bar', figsize=(20,10))

# %% [markdown]
# #### 1.6 What if we used a different metric?

# %% [markdown]
# What we would like to capture is this: a singer should to be scored higher if the singer appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %%
#把数据放入一个字典中
score_singers_list = {}
score_frame = pd.DataFrame(flatframe, columns = ['band_singer', 'ranking'])
for i in range(len(score_frame.values)):
    if score_frame.iloc[i, 0] not in score_singers_list:
        score_singers_list[score_frame.iloc[i, 0]] = 101-score_frame.iloc[i, 1]
    else:
        score_singers_list[score_frame.iloc[i, 0]] += 101-score_frame.iloc[i, 1]
score_singers = pd.Series(score_singers_list)

# %%
score_singers.sort_values(ascending=False)[:20].plot(kind='bar', figsize=(10,10))

# %% [markdown]
# #### 1.7 Do you notice any major differences when you change the metric?
#
# How have the singers at the top shifted places? Why do you think this happens?

# %% [markdown]
# 上榜次数多的也是总评分最高的，这也是比较容易理解的，上榜次数越多歌手/乐队说明他们十分受欢迎，受欢迎的歌手/乐队也自然有许多人们喜欢的歌曲，自然歌曲的总评分也是很高的。

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those band/singer urls we collected under `flatframe.url` and get information about singers and/or bands.

# %% [markdown]
# ### Scrape information about artists from wikipedia

# %% [markdown]
# We wish to fetch information about the singers or groups for all the winning songs in a list of years.
#
# Here we show a function that fetches information about a singer or group from their url on wikipedia. We create a cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Once we have fetched information about an artist, we don't need to do it again. The caching also helps if the network goes down, or the target website is having some problems. You simply need to run the `get_page` function below again, and the `urlcache` dictionary will continue to be filled.
#
# If the request gets an HTTP return code different from 200, (such as a 404 not found or 500 Internal Server Error) the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.
#
# Notice that we have wrapped the call in whats called _an exception block_. We try to make the request. If it fails entirely, or returns a HTTP code thats not 200, we set the status to 2 and 1 respectively.

# %%
urlcache={}

# %%
def get_page(url):
    # Check if URL has already been visited.
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        # try/except blocks are used whenever the code could generate an exception (e.g. division by zero).
        # In this case we don't know if the page really exists, or even if it does, if we'll be able to reach it.
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)

            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# We sort the `flatframe` by year, ascending, first. Think why.

# %%
flatframe=flatframe.sort_values('year')
flatframe.head(50)
# Out:
#     year                 band_singer  ranking                                              song                                            songurl                             url
# 0   1994                 Ace of Base        1                                        "The Sign"                              /wiki/The_Sign_(song)               /wiki/Ace_of_Base
# 53  1994             The Cranberries       49                                          "Linger"                                /wiki/Linger_(song)           /wiki/The_Cranberries
# 2   1994                 Boyz II Men        3                           "I'll Make Love to You"                      /wiki/I%27ll_Make_Love_to_You               /wiki/Boyz_II_Men
# 3   1994                 Céline Dion        4                               "The Power of Love"  /wiki/The_Power_of_Love_(Jennifer_Rush_song)#C...          /wiki/C%C3%A9line_Dion
# 4   1994                Mariah Carey        5                                            "Hero"                     /wiki/Hero_(Mariah_Carey_song)              /wiki/Mariah_Carey
# 5   1994  Lisa Loeb and Nine Stories        6                             "Stay (I Missed You)"                          /wiki/Stay_(I_Missed_You)                 /wiki/Lisa_Loeb
# 6   1994                Toni Braxton        7                                   "Breathe Again"                                /wiki/Breathe_Again              /wiki/Toni_Braxton
# 7   1994                 Bryan Adams        8                                    "All for Love"                          /wiki/All_for_Love_(song)               /wiki/Bryan_Adams
# 8   1994                 Rod Stewart        8                                    "All for Love"                          /wiki/All_for_Love_(song)               /wiki/Rod_Stewart
# 9   1994                       Sting        8                                    "All for Love"                          /wiki/All_for_Love_(song)          /wiki/Sting_(musician)
# 10  1994                 Ace of Base        9                              "All That She Wants"                           /wiki/All_That_She_Wants               /wiki/Ace_of_Base
# 11  1994                 Ace of Base       10                               "Don't Turn Around"                          /wiki/Don%27t_Turn_Around               /wiki/Ace_of_Base
# 13  1994               Janet Jackson       12                                           "Again"                   /wiki/Again_(Janet_Jackson_song)             /wiki/Janet_Jackson
# 25  1994                    Warren G       22                                        "Regulate"                              /wiki/Regulate_(song)                  /wiki/Warren_G
# 14  1994                     Madonna       13                                   "I'll Remember"                              /wiki/I%27ll_Remember     /wiki/Madonna_(entertainer)
# 15  1994                 Salt-n-Pepa       14                                      "Whatta Man"                                   /wiki/Whatta_Man               /wiki/Salt-n-Pepa
# 16  1994                    En Vogue       14                                      "Whatta Man"                                   /wiki/Whatta_Man                  /wiki/En_Vogue
# 17  1994             John Mellencamp       15                                      "Wild Night"                                   /wiki/Wild_Night           /wiki/John_Mellencamp
# 18  1994         Meshell Ndegeocello       15                                      "Wild Night"                                   /wiki/Wild_Night       /wiki/Meshell_Ndegeocello
# 19  1994                Mariah Carey       16                                    "Without You"   /wiki/Without_You_(Badfinger_song)#Mariah_Care...              /wiki/Mariah_Carey
# 20  1994                Toni Braxton       17                        "You Mean the World to Me"                     /wiki/You_Mean_the_World_to_Me              /wiki/Toni_Braxton
# 21  1994                  Elton John       18                   "Can You Feel the Love Tonight"                /wiki/Can_You_Feel_the_Love_Tonight                /wiki/Elton_John
# 22  1994                      Prince       19            "The Most Beautiful Girl in the World"  /wiki/The_Most_Beautiful_Girl_in_the_World_(Pr...         /wiki/Prince_(musician)
# 23  1994                      Coolio       20                                "Fantastic Voyage"               /wiki/Fantastic_Voyage_(Coolio_song)                    /wiki/Coolio
# 26  1994                   Nate Dogg       22                                        "Regulate"                              /wiki/Regulate_(song)                 /wiki/Nate_Dogg
# 24  1994                Big Mountain       21                           "Baby, I Love Your Way"                        /wiki/Baby,_I_Love_Your_Way       /wiki/Big_Mountain_(band)
# 1   1994                   All-4-One        2                                         "I Swear"                    /wiki/I_Swear#All-4-One_version                 /wiki/All-4-One
# 51  1994                Mariah Carey       47                       "Anytime You Need a Friend"                    /wiki/Anytime_You_Need_a_Friend              /wiki/Mariah_Carey
# 33  1994                 Salt-n-Pepa       29                                           "Shoop"                                 /wiki/Shoop_(song)               /wiki/Salt-n-Pepa
# 37  1994                      Enigma       33                             "Return to Innocence"                          /wiki/Return_to_Innocence  /wiki/Enigma_(musical_project)
# 36  1994              Michael Bolton       32                   "Said I Loved You...But I Lied"                /wiki/Said_I_Loved_You...But_I_Lied            /wiki/Michael_Bolton
# 35  1994             Collective Soul       31                                           "Shine"                 /wiki/Shine_(Collective_Soul_song)           /wiki/Collective_Soul
# 34  1994               Janet Jackson       30                             "Any Time, Any Place"                          /wiki/Any_Time,_Any_Place             /wiki/Janet_Jackson
# 31  1994                 Bryan Adams       27                               "Please Forgive Me"                            /wiki/Please_Forgive_Me               /wiki/Bryan_Adams
# 32  1994                   All-4-One       28                                 "So Much in Love"                              /wiki/So_Much_in_Love                 /wiki/All-4-One
# 39  1994          Crash Test Dummies       35                                 "Mmm Mmm Mmm Mmm"                              /wiki/Mmm_Mmm_Mmm_Mmm        /wiki/Crash_Test_Dummies
# 30  1994                    Babyface       26                              "When Can I See You"                           /wiki/When_Can_I_See_You       /wiki/Babyface_(musician)
# 29  1994                Richard Marx       25                                 "Now and Forever"          /wiki/Now_and_Forever_(Richard_Marx_song)              /wiki/Richard_Marx
# 28  1994                     Aaliyah       24                                    "Back & Forth"                /wiki/Back_%26_Forth_(Aaliyah_song)                   /wiki/Aaliyah
# 38  1994                 Sheryl Crow       34                                  "All I Wanna Do"            /wiki/All_I_Wanna_Do_(Sheryl_Crow_song)               /wiki/Sheryl_Crow
# 41  1994                     Da Brat       37                                      "Funkdafied"                            /wiki/Funkdafied_(song)                   /wiki/Da_Brat
# 40  1994              Tevin Campbell       36                                     "Can We Talk"                                  /wiki/Can_We_Talk            /wiki/Tevin_Campbell
# 42  1994                   Meat Loaf       38  "I'd Do Anything for Love (But I Won't Do That)"  /wiki/I%27d_Do_Anything_for_Love_(But_I_Won%27...                 /wiki/Meat_Loaf
# 43  1994                         DRS       39                                    "Gangsta Lean"                          /wiki/Gangsta_Lean_(song)               /wiki/DRS_(group)
# 44  1994              10,000 Maniacs       40                               "Because the Night"                            /wiki/Because_the_Night            /wiki/10,000_Maniacs
# 27  1994                  Jon Secada       23                                       "If You Go"                             /wiki/If_You_Go_(song)                /wiki/Jon_Secada
# 46  1994                    Tag Team       42                           "Whoomp! (There It Is)"                        /wiki/Whoomp!_(There_It_Is)          /wiki/Tag_Team_(group)
# 47  1994           Melissa Etheridge       43                               "Come to My Window"                            /wiki/Come_to_My_Window         /wiki/Melissa_Etheridge
# 48  1994              Changing Faces       44                                   "Stroke You Up"                                /wiki/Stroke_You_Up    /wiki/Changing_Faces_(group)
# 49  1994              Tevin Campbell       45                                       "I'm Ready"            /wiki/I%27m_Ready_(Tevin_Campbell_song)            /wiki/Tevin_Campbell

# %% [markdown]
# #### Pulling and saving the data

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
# Here we are populating the url cache
# subsequent calls to this cell should be very fast, since Python won't
# need to fetch the page from the web server.
# NOTE this function will take quite some time to run (about 30 mins for me), since we sleep 1 second before
# making a request. If you run it again it will be almost instantaneous, save requests that might have failed
# (you will need to run it again if requests fail..see cell below for how to test this)
flatframe["url"].apply(get_page)
# Out:
# 0       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 78      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 77      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 76      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 75      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 74      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 73      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 72      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 71      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 70      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 69      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 68      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 67      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 66      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 65      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 64      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 63      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 62      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 61      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 60      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 59      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 58      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 57      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 56      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 80      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 55      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 81      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 83      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 106     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 105     <!DOCTYPE html>\n<html class="client-nojs" lan...
#                               ...
# 2689    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2690    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2691    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2692    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2693    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2694    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2695    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2696    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2697    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2682    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2661    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2681    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2679    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2663    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2665    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2666    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2667    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2668    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2669    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2670    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2671    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2672    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2673    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2674    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2675    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2676    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2677    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2678    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2680    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2774    <!DOCTYPE html>\n<html class="client-nojs" lan...
# Name: url, Length: 2775, dtype: object

# %% [markdown]
# You may have to run this function again and again, in case there were network problems. Note that, because there is a "global" cache, it will take less time each time you run it. Also note that this function is designed to be run again and again: it attempts to make sure that there are no unresolved pages remaining. Let us make sure of this: *the sum below should be 0, and the boolean True.*

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
print("Number of bad requests:",np.sum([(urlcache[k]==1) or (urlcache[k]==2) for k in urlcache])) # no one or 0's)
print("Did we get all urls?", len(flatframe.url.unique())==len(urlcache)) # we got all of the urls
# Out:
# Number of bad requests: 0
# Did we get all urls? True

# %% [markdown]
# Let's save the `urlcache` to disk, just in case we need it again.

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
with open("data/artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %%
# RERUN WHEN SUBMITTING
with open("data/artistinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# #### 2.1 Extract information about singers and bands

# %% [markdown]
# From each page we collected about a singer or a band, extract the following information:
#
# 1. If the page has the text "Born" in the sidebar on the right, extract the element with the class `.bday`. If the page doesn't contain "Born", store `False`.  Store either of these into the variable `born`. We want to analyze the artist's age.
#
# 2. If the text "Years active" is found, but no "born", assume a band. Store into the variable `ya` the value of the next table cell corresponding to this, or `False` if the text is not found.
#
# Put this all into a function `singer_band_info` which takes the singer/band url as argument and returns a dictionary `dict(url=url, born=born, ya=ya)`.
#
# The information can be found on the sidebar on each such wikipedia page, as the example here shows:
#
# ![sandg](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/sandg.png).

# %% [markdown]
# Write the function `singer_band_info` according to the following specification:

# %%
#测试用
#HTML(urlcache[1])
test_page=urlcache['/wiki/Lil_Jon']
test_soup = BeautifulSoup(test_page, 'html.parser')
infobox = test_soup.find('table', class_='vcard'or'info')
trs =infobox.find_all('tr')
for obj in trs:
    if obj.find('th') != None:
        if obj.find('th').text == 'Born':
            B = obj.find('td')
        
B
# Out:
# <td><span style="display:none">(<span class="bday">1971-01-17</span>)</span> January 17, 1971 <span class="noprint ForceAgeToShow">(age 46)</span><br/>
# <a href="/wiki/Atlanta" title="Atlanta">Atlanta</a>, Georgia, U.S.</td>

# %%
#测试用
trs =infobox.find_all('tr')
ya = False
for obj in trs:
    if obj.find(class_='nowrap') != None:
        #print(obj.find(class_='nowrap'))
        if obj.find(class_='nowrap').text == 'Years active':
            ya = obj.find('td').text

print(ya)
# Out:
# 1993–present

# %%
#dict(url=url, born=born, ya=ya)
def singer_band_info(url):
    #print(url)
    dict = {'url':url}
    bo = False
    ya = False
    page=urlcache[url]
    soup = BeautifulSoup(page, 'html.parser')
    sidebar = soup.find('table', class_='infobox'or'vcard') #sidebar的元素会略有不同
    if sidebar == None:
        dict['born'] = bo
        dict['ya'] = ya
        return dict
    trs =sidebar.find_all('tr')
    for obj in trs:
        if obj.find('th') != None:
            if obj.find('th').text == 'Born':
                if obj.find(class_='bday') != None:  #有些有Born的没bday
                    bo = obj.find(class_='bday').text 
        if obj.find(class_='nowrap') != None:
            if obj.find(class_='nowrap').text == 'Years active':
                ya = obj.find('td').text
    dict['born'] = bo
    dict['ya']=ya
    return dict

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""

# %% [markdown]
# #### 2.2  Merging this information in

# %% [markdown]
# Iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a dataframe from there with columns `url`, `born`, and `ya`. Merge this dataframe on the `url` key with `flatframe`, creating a rather wide dataframe that we shall call `largedf`. It should look something like this:
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC3.png)
#
# Notice how the `born` and `ya` and `url` are repeated every time a different song from a given band is represented in a row.

# %%
from bs4 import BeautifulSoup

# %%
band_singer_list = [singer_band_info(url) for url in urlcache.keys()]

# %%
#重开notebook时别运行这个
import json
fd = open("data/band_singer_info.json","w")
json.dump(band_singer_list, fd)
fd.close()

# %%
with open("data/band_singer_info.json") as json_file:
    band_singer_list = json.load(json_file)

# %%
band_singer_df = pd.DataFrame(band_singer_list, columns = ['url', 'born', 'ya'])
largedf = flatframe.merge(band_singer_df, on = 'url', how = 'inner')
largedf
# Out:
#       year              band_singer  ranking                         song                                            songurl                              url        born                        ya
# 0     1994              Ace of Base        1                   "The Sign"                              /wiki/The_Sign_(song)                /wiki/Ace_of_Base       False                 1990–2012
# 1     1994              Ace of Base        9         "All That She Wants"                           /wiki/All_That_She_Wants                /wiki/Ace_of_Base       False                 1990–2012
# 2     1994              Ace of Base       10          "Don't Turn Around"                          /wiki/Don%27t_Turn_Around                /wiki/Ace_of_Base       False                 1990–2012
# 3     1996              Ace of Base       94             "Beautiful Life"            /wiki/Beautiful_Life_(Ace_of_Base_song)                /wiki/Ace_of_Base       False                 1990–2012
# 4     1998              Ace of Base       66               "Cruel Summer"                          /wiki/Cruel_Summer_(song)                /wiki/Ace_of_Base       False                 1990–2012
# 5     1994                All-4-One        2                    "I Swear"                    /wiki/I_Swear#All-4-One_version                  /wiki/All-4-One       False       1993 (1993)–present
# 6     1994                All-4-One       28            "So Much in Love"                              /wiki/So_Much_in_Love                  /wiki/All-4-One       False       1993 (1993)–present
# 7     1995                All-4-One       15   "I Can Love You Like That"                     /wiki/I_Can_Love_You_Like_That                  /wiki/All-4-One       False       1993 (1993)–present
# 8     1994              Boyz II Men        3      "I'll Make Love to You"                      /wiki/I%27ll_Make_Love_to_You                /wiki/Boyz_II_Men       False              1985–present
# 9     1995              Boyz II Men        5             "On Bended Knee"                               /wiki/On_Bended_Knee                /wiki/Boyz_II_Men       False              1985–present
# 10    1995              Boyz II Men       12             "Water Runs Dry"                               /wiki/Water_Runs_Dry                /wiki/Boyz_II_Men       False              1985–present
# 11    1995              Boyz II Men       50      "I'll Make Love to You"                      /wiki/I%27ll_Make_Love_to_You                /wiki/Boyz_II_Men       False              1985–present
# 12    1995              Boyz II Men       94                  "Thank You"                 /wiki/Thank_You_(Boyz_II_Men_song)                /wiki/Boyz_II_Men       False              1985–present
# 13    1996              Boyz II Men        2              "One Sweet Day"                                /wiki/One_Sweet_Day                /wiki/Boyz_II_Men       False              1985–present
# 14    1997              Boyz II Men       30    "4 Seasons of Loneliness"                      /wiki/4_Seasons_of_Loneliness                /wiki/Boyz_II_Men       False              1985–present
# 15    1998              Boyz II Men       30            "A Song for Mama"                              /wiki/A_Song_for_Mama                /wiki/Boyz_II_Men       False              1985–present
# 16    1998              Boyz II Men       96    "4 Seasons of Loneliness"                      /wiki/4_Seasons_of_Loneliness                /wiki/Boyz_II_Men       False              1985–present
# 17    1994              Céline Dion        4          "The Power of Love"  /wiki/The_Power_of_Love_(Jennifer_Rush_song)#C...           /wiki/C%C3%A9line_Dion  1968-03-30                     False
# 18    1994             Mariah Carey        5                       "Hero"                     /wiki/Hero_(Mariah_Carey_song)               /wiki/Mariah_Carey  1969-03-27                     False
# 19    1994             Mariah Carey       16               "Without You"   /wiki/Without_You_(Badfinger_song)#Mariah_Care...               /wiki/Mariah_Carey  1969-03-27                     False
# 20    1994             Mariah Carey       47  "Anytime You Need a Friend"                    /wiki/Anytime_You_Need_a_Friend               /wiki/Mariah_Carey  1969-03-27                     False
# 21    1994             Mariah Carey       56               "Endless Love"  /wiki/Endless_Love_(song)#Luther_Vandross_and_...               /wiki/Mariah_Carey  1969-03-27                     False
# 22    1995             Mariah Carey        7                    "Fantasy"                  /wiki/Fantasy_(Mariah_Carey_song)               /wiki/Mariah_Carey  1969-03-27                     False
# 23    1996             Mariah Carey        2              "One Sweet Day"                                /wiki/One_Sweet_Day               /wiki/Mariah_Carey  1969-03-27                     False
# 24    1996             Mariah Carey        5          "Always Be My Baby"                            /wiki/Always_Be_My_Baby               /wiki/Mariah_Carey  1969-03-27                     False
# 25    1996             Mariah Carey       49                    "Fantasy"                  /wiki/Fantasy_(Mariah_Carey_song)               /wiki/Mariah_Carey  1969-03-27                     False
# 26    1997             Mariah Carey       32                      "Honey"                    /wiki/Honey_(Mariah_Carey_song)               /wiki/Mariah_Carey  1969-03-27                     False
# 27    1998             Mariah Carey       17                     "My All"                                       /wiki/My_All               /wiki/Mariah_Carey  1969-03-27                     False
# 28    1999             Mariah Carey       35               "Heartbreaker"             /wiki/Heartbreaker_(Mariah_Carey_song)               /wiki/Mariah_Carey  1969-03-27                     False
# 29    1999             Mariah Carey       36            "I Still Believe"       /wiki/I_Still_Believe_(Brenda_K._Starr_song)               /wiki/Mariah_Carey  1969-03-27                     False
# ...    ...                      ...      ...                          ...                                                ...                              ...         ...                       ...
# 2745  2014                       YG       42             "Don't Tell 'Em"                           /wiki/Don%27t_Tell_%27Em                /wiki/YG_(rapper)  1990-03-09              2009–present
# 2746  2014                       YG       58                   "My Hitta"                                     /wiki/My_Nigga                /wiki/YG_(rapper)  1990-03-09              2009–present
# 2747  2014                  Kid Ink       43                    "Show Me"                       /wiki/Show_Me_(Kid_Ink_song)                    /wiki/Kid_Ink  1986-04-01              2010–present
# 2748  2014               Aloe Blacc       48                    "The Man"                    /wiki/The_Man_(Aloe_Blacc_song)                 /wiki/Aloe_Blacc  1979-01-07              1995–present
# 2749  2014                     MKTO       50                    "Classic"                          /wiki/Classic_(MKTO_song)                       /wiki/MKTO       False               2010 – 2017
# 2750  2014            Bobby Shmurda       54                    "Hot Boy"                                    /wiki/Hot_Nigga              /wiki/Bobby_Shmurda  1994-08-04                 2004–2014
# 2751  2014                    Jeezy       58                   "My Hitta"                                     /wiki/My_Nigga                      /wiki/Jeezy  1977-09-28              1998–present
# 2752  2014          Rich Homie Quan       58                   "My Hitta"                                     /wiki/My_Nigga            /wiki/Rich_Homie_Quan  1989-10-04              2007–present
# 2753  2014          Rich Homie Quan       72                  "Lifestyle"                             /wiki/Lifestyle_(song)            /wiki/Rich_Homie_Quan  1989-10-04              2007–present
# 2754  2014                Echosmith       59                  "Cool Kids"                   /wiki/Cool_Kids_(Echosmith_song)                  /wiki/Echosmith       False              2009–present
# 2755  2014                  Tinashe       65                       "2 On"                                         /wiki/2_On                    /wiki/Tinashe  1993-02-06              2007–present
# 2756  2014              ScHoolboy Q       65                       "2 On"                                         /wiki/2_On                /wiki/ScHoolboy_Q  1986-10-26              2009–present
# 2757  2014              ScHoolboy Q       92                "White Walls"                                  /wiki/White_Walls                /wiki/ScHoolboy_Q  1986-10-26              2009–present
# 2758  2014              ScHoolboy Q       96                     "Studio"                                /wiki/Studio_(song)                /wiki/ScHoolboy_Q  1986-10-26              2009–present
# 2759  2014         Brantley Gilbert       68                 "Bottoms Up"           /wiki/Bottoms_Up_(Brantley_Gilbert_song)           /wiki/Brantley_Gilbert  1985-01-20              2005–present
# 2760  2014                  Becky G       69                     "Shower"                                /wiki/Shower_(song)                    /wiki/Becky_G  1997-03-02                     False
# 2761  2014                   Rixton       70     "Me and My Broken Heart"                       /wiki/Me_and_My_Broken_Heart              /wiki/Rixton_(band)       False              2012–present
# 2762  2014            Martin Garrix       71                    "Animals"          /wiki/Animals_(Martin_Garrix_composition)              /wiki/Martin_Garrix  1996-05-14                     False
# 2763  2014                Rich Gang       72                  "Lifestyle"                             /wiki/Lifestyle_(song)                  /wiki/Rich_Gang       False                     False
# 2764  2014               Young Thug       72                  "Lifestyle"                             /wiki/Lifestyle_(song)                 /wiki/Young_Thug  1991-08-16              2011–present
# 2765  2014        The Neighbourhood       75            "Sweater Weather"                              /wiki/Sweater_Weather          /wiki/The_Neighbourhood       False           2011–present[1]
# 2766  2014                 Sam Hunt       76         "Leave the Night On"                           /wiki/Leave_the_Night_On        /wiki/Sam_Hunt_(musician)  1984-12-08              2009–present
# 2767  2014              Naughty Boy       82                   "La La La"                  /wiki/La_La_La_(Naughty_Boy_song)                /wiki/Naughty_Boy  1985-01-01              2005–present
# 2768  2014      5 Seconds of Summer       86                    "Amnesia"           /wiki/Amnesia_(5_Seconds_of_Summer_song)        /wiki/5_Seconds_of_Summer       False              2011–present
# 2769  2014      5 Seconds of Summer       93       "She Looks So Perfect"                         /wiki/She_Looks_So_Perfect        /wiki/5_Seconds_of_Summer       False              2011–present
# 2770  2014                   KONGOS       88           "Come with Me Now"                             /wiki/Come_with_Me_Now              /wiki/Kongos_(band)       False       2007 (2007)–present
# 2771  2014        Mike WiLL Made-It       90                         "23"                                    /wiki/23_(song)          /wiki/Mike_WiLL_Made-It  1989-03-23              2005–present
# 2772  2014  Macklemore & Ryan Lewis       92                "White Walls"                                  /wiki/White_Walls  /wiki/Macklemore_%26_Ryan_Lewis       False  2008–2017 (on hiatus)[1]
# 2773  2014                   Hollis       92                "White Walls"                                  /wiki/White_Walls            /wiki/Hollis_(singer)       False              2013–present
# 2774  2014       BJ the Chicago Kid       96                     "Studio"                                /wiki/Studio_(song)         /wiki/BJ_the_Chicago_Kid  1984-11-23              2001–present
#
# [2775 rows x 8 columns]

# %% [markdown]
# #### 2.3 What is the age at which singers achieve their top ranking?

# %% [markdown]
# Plot a histogram of the age at which singers achieve their top ranking. What conclusions can you draw from this distribution of ages?
#
# *HINT: You will need to do some manipulation of the `born` column, and find the song for which a band or an artist achieves their top ranking. You will then need to put these rows together into another dataframe or array to make the plot.*

# %%
#先建立一个歌手/乐队-最高ranking和年份的字典
singer_best_ranking = {}
score_frame = pd.DataFrame(largedf, columns = ['band_singer', 'ranking', 'year', 'born','ya'])
for i in range(len(score_frame.values)):
    if score_frame.iloc[i, 0] not in singer_best_ranking.keys():
        singer_best_ranking[score_frame.iloc[i, 0]]={'best_ranking': score_frame.iloc[i, 1], 'year':score_frame.iloc[i, 2],
                                                     'born':score_frame.iloc[i, 3], 'ya':score_frame.iloc[i, 4]}
    else:
        if score_frame.iloc[i, 1]<singer_best_ranking[score_frame.iloc[i, 0]]['best_ranking']:
            singer_best_ranking[score_frame.iloc[i, 0]]['best_ranking'] = score_frame.iloc[i, 1]
            singer_best_ranking[score_frame.iloc[i, 0]]['year'] = score_frame.iloc[i, 2]
            singer_best_ranking[score_frame.iloc[i, 0]]['born'] = score_frame.iloc[i, 3]
            singer_best_ranking[score_frame.iloc[i, 0]]['ya'] = score_frame.iloc[i, 4]

# %%
#再依据原字典建立一best_ranking与年龄的字典
br_age = {}
for singer in singer_best_ranking.keys():
    #print(singer)
    if type(singer_best_ranking[singer]['born']) == str:
        br_age[singer] = singer_best_ranking[singer]['year']-int(singer_best_ranking[singer]['born'][:4])

# %%
best_ranking_age = pd.Series(br_age)
best_ranking_age.plot(kind = 'hist', bins = 30, figsize=(8,8))

# %% [markdown]
# 大多数上榜歌手获得最高排名的年龄在20-35岁之间。

# %% [markdown]
# #### 2.4 At what year since inception do bands reach their top rankings?

# %% [markdown]
# Make a similar calculation to plot a histogram of the years since inception at which bands reach their top ranking. What conclusions can you draw?

# %%
brb_time = {}
for band in singer_best_ranking.keys():
    #print(singer)
    if singer_best_ranking[band]['born'] == False:
        if singer_best_ranking[band]['ya'] != False:
            time = singer_best_ranking[band]['year']-int(singer_best_ranking[band]['ya'][:4])
            if time>100:  #防止格式不一样造成错误
                continue
            brb_time[band] = time

# %%
br_band_time = pd.Series(brb_time)
br_band_time.hist(bins = 50, figsize=(8,8))

# %% [markdown]
# 绝大多数上榜乐队在他们出道前十年内就获得了他们的最高排名。
